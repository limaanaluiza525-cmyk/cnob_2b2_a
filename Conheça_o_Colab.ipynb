# %% [markdown]
# <a href="https://colab.research.google.com/github/limaanaluiza525-cmyk/cnob_2b2_a/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Fórmula da velocidade

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# ##Teste Serviço Nuvem: Velocidade Média

# %%
print("Vm=", calculaVelMedia(30, 15))
# Out:
# Vm= 2.0

# %% [markdown]
# ##Fórmula da aceleração

# %%
def calculaAceleracao(vf, vi, t):
  return(vf - vi) / t

# %% [markdown]
# ##teste de função de aceleração

# %%
 print("a=",calculaAceleracao(30, 10, 5))
# Out:
# a= 4.0

# %% [markdown]
# ##Fórmulas do Movimento Uniforme

# %%
def MovimentoUniforme(s0, v, t):
  return s0 + v * t

# %% [markdown]
# ##Teste de movimento uniforme

# %%
  print("s=", MovimentoUniforme(0, 10, 5))
# Out:
# s= 50

# %% [markdown]
# ##Função horária do deslocamento

# %%
def calculaDesloc(inciai, deltaT, v):
  d = inicialS + (v*deltaT)
  return d

# %% [markdown]
# ##Testes de Função : Horária de Deslocamento

# %%
print("deslocamento= ", calculaDesloc(0, 15, 30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_358/1529115979.py in <cell line: 0>()
# ----> 1 print("deslocamento= ",calculaDesloc(0, 15, 30))
#
# NameError: name 'calculaDesloc' is not defined

# %% [markdown]
# ##Fórmulas do Movimento Uniformemente Variado

# %%
def MovimentoUniformeVariado(s0, v, t):
  return s0 + v * t

# %% [markdown]
# ##teste de função : Movimestos Uniformes Variado

# %%
  print("s=", MovimentoUniformeVariado(0, 10, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16410/3918859657.py in <cell line: 0>()
# ----> 1 print("s=", MovimentoUniformeVariado(0, 10, 5))
#
# NameError: name 'MovimentoUniformeVariado' is not defined

# %% [markdown]
# # Nova seção

# %% [markdown]
# ##Função horária da velocidade

# %%
def calVelocidadeHoraria(vInicial, acel, tempo):
  vh= vInicial +(acel * tempo)
  return vh

# %%
print("Velocidade Horaria:" calVelocidadeHoraria(12, 25, 78))

# %% [markdown]
# ##Teste de funçao

# %%
print("velocidade:" , velocidade(10, 2, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16410/3294514267.py in <cell line: 0>()
# ----> 1 print("velocidade:" , velocidade(10, 2, 5))
#
# NameError: name 'velocidade' is not defined

# %% [markdown]
# ##Função horária da posição

# %% [markdown]
# ##Equação de Torricelli

# %%
import math
def calrricelli(vZero, acel, des):
  t=2*acel*des
  v=vZero+t
  res = round(math,sqrt(v),2)
  return res

# %% [markdown]
# ##teste de funçao

# %%
print("calcule de torricelli:", calTorricelli(0,3,8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16410/1337742161.py in <cell line: 0>()
# ----> 1 print("calcule de torricelli:", calTorricelli(0,3,8))
#
# NameError: name 'calTorricelli' is not defined

# %% [markdown]
# ##Fórmula do movimento vertical
